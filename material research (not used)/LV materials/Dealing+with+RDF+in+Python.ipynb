# %% [markdown]
# # The RDFlib library
#
# The [RDFlib](https://github.com/RDFLib/rdflib) Python library allows you to parse and generate RDF in Python.
# Note that the library mostly was developed using Python 2.7 still, so the examples in the [Documentation](https://github.com/RDFLib/rdflib/tree/master/docs) mostly use Python2.7, i.e. you have to take care of small differences when trying them out, such as for instance putting parentheses after print(...) commands, etc.
#
# Note that the library might not be installed upfront in your Python environment.
# You can install the library easiest using easy_install, cf. the library's [README](https://github.com/RDFLib/rdflib/blob/master/README.md).
#
# In our Docker container, I installed the library using this command (i.e., if you work with our docker image, you don't need to do that):

# %% [markdown]
# `$ easy_install-3.5 rdflib`

# %% [markdown]
# ### An example for loading RDF
#
# Let's load an RDF graph in the simple [Turtle](https://www.w3.org/TR/turtle/) format from https://aic.ai.wu.ac.at/~polleres/teaching/SemWebTech_2012/testdata/foaf.ttl and print the number of triples (statements in this graph)

# %%
# loading RDF in Turtle format
# Note to self: you actually have to know the format upfront to decide which parter to use?

import rdflib
g=rdflib.Graph()
g.parse('https://aic.ai.wu.ac.at/~polleres/teaching/SemWebTech_2012/testdata/foaf.ttl',format='turtle')

# for stmnt in g:
#    print(stmnt)

len(g)
# Out:
# 178

# %%
# and now some in-memory SPARQL querying using RDFlib's native SPARQL query engine:

qres = g.query("""SELECT DISTINCT ?O WHERE {
          # ?S ?P ?O .
       }""")

for row in qres: print(row)
# Out:
# (rdflib.term.URIRef('http://skype.com/'),)
# (rdflib.term.URIRef('http://richard.cyganiak.de/foaf.rdf'),)
# (rdflib.term.URIRef('fax:+33591495541'),)
# (rdflib.term.Literal('Anna V. Zhdanova'),)
# (rdflib.term.URIRef('http://thefigtrees.net/lee/ldf-card'),)
# (rdflib.term.URIRef('http://twitter.com/'),)
# (rdflib.term.URIRef('http://members.deri.at/~jamess/foaf_james.xml'),)
# (rdflib.term.URIRef('http://twitter2foaf.appspot.com/user/AxelPolleres'),)
# (rdflib.term.Literal('Polleres'),)
# (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/Person'),)
# (rdflib.term.URIRef('http://www.facebook.com/'),)
# (rdflib.term.URIRef('http://eyaloren.org/foaf.rdf'),)
# (rdflib.term.URIRef('http://www.siegfried-handschuh.net/'),)
# (rdflib.term.URIRef('http://www.urjc.es/'),)
# (rdflib.term.URIRef('http://sw.deri.org/~aidanh/foaf/foaf.rdf#Aidan_Hogan'),)
# (rdflib.term.URIRef('http://www.polleres.net/images/axel.jpg'),)
# (rdflib.term.Literal('Thomas Eiter'),)
# (rdflib.term.BNode('Nb90485f59dd642cab7cec63945459d99'),)
# (rdflib.term.Literal('Pascal Hitzler'),)
# (rdflib.term.URIRef('http://www.armin-haller.com/'),)
# (rdflib.term.URIRef('http://www.gibbi.com/foaf.rdf'),)
# (rdflib.term.Literal('Aidan Hogan'),)
# (rdflib.term.URIRef('http://www.polleres.net/foaf.rdf'),)
# (rdflib.term.URIRef('http://www.linkedin.com/'),)
# (rdflib.term.URIRef('http://tinf2.vub.ac.be/~sheymans/foaf.rdf'),)
# (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/Document'),)
# (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/OnlineAccount'),)
# (rdflib.term.URIRef('http://www-cdr.stanford.edu/~petrie/foaf.rdf'),)
# (rdflib.term.URIRef('http://semanticweb.org/id/Axel_Polleres'),)
# (rdflib.term.Literal('Axel'),)
# (rdflib.term.URIRef('http://page.mi.fu-berlin.de/~nixon/foaf.rdf'),)
# (rdflib.term.URIRef('http://g1o.net/foaf.rdf'),)
# (rdflib.term.URIRef('callto://droxel'),)
# (rdflib.term.URIRef('http://nunolopes.org/foaf.rdf#me'),)
# (rdflib.term.URIRef('http://www.wikier.org/foaf.rdf'),)
# (rdflib.term.URIRef('http://www.johnbreslin.com/foaf/foaf.rdf#me'),)
# (rdflib.term.Literal("Eric Gordon Prud'hommeaux"),)
# (rdflib.term.URIRef('http://twitter.com/AxelPolleres'),)
# (rdflib.term.BNode('N957681edd7ef4143988674fa70a5e5c1'),)
# (rdflib.term.URIRef('http://dblp.l3s.de/d2r/page/authors/Axel_Polleres'),)
# (rdflib.term.Literal('Manfred Hauswirth'),)
# (rdflib.term.Literal('Stefan Decker'),)
# (rdflib.term.URIRef('http://nunolopes.org/foaf.rdf'),)
# (rdflib.term.URIRef('http://www.polleres.net/foaf.rdf#me'),)
# (rdflib.term.URIRef('http://richard.cyganiak.de/foaf.rdf#cygri'),)
# (rdflib.term.URIRef('http://www.linkedin.com/pub/axel-polleres/1/246/71'),)
# (rdflib.term.URIRef('http://www.deri.ie/fileadmin/scripts/foaf.php?id=174'),)
# (rdflib.term.URIRef('http://sw.deri.org/~haller/foaf.rdf'),)
# (rdflib.term.Literal('Dr'),)
# (rdflib.term.Literal('Alexandre Passant'),)
# (rdflib.term.URIRef('http://nets.ii.uam.es/~rlara/foaf.rdf#me'),)
# (rdflib.term.URIRef('http://www.cs.rpi.edu/~hendler/'),)
# (rdflib.term.Literal('Axel Polleres'),)
# (rdflib.term.Literal('AxelPolleres'),)
# (rdflib.term.URIRef('http://www.johnbreslin.com/foaf/foaf.rdf'),)
# (rdflib.term.Literal('35a8d4858ba240996a6f71836d93fbfdcd2b4843'),)
# (rdflib.term.URIRef('http://www.stefandecker.org/'),)
# (rdflib.term.URIRef('http://www.deri.ie/fileadmin/scripts/foaf.php?id=12'),)
# (rdflib.term.Literal('Armin Haller'),)
# (rdflib.term.Literal('Malgorzata Mochol'),)
# (rdflib.term.Literal('Francois Scharffe'),)
# (rdflib.term.URIRef('http://g1o.net/'),)
# (rdflib.term.URIRef('http://www.real-programmer.com/foaf/chbussler.foaf'),)
# (rdflib.term.Literal("Eric Prud'hommeaux"),)
# (rdflib.term.Literal('Giovanni Tummarello'),)
# (rdflib.term.URIRef('http://www4.wiwiss.fu-berlin.de/dblp/resource/person/100566'),)
# (rdflib.term.Literal('Siegfried Handschuh'),)
# (rdflib.term.URIRef('http://www-di.inf.puc-rio.br/schwabe/'),)
# (rdflib.term.URIRef('http://www.cs.rpi.edu/~hendler/foaf.rdf#jhendler'),)
# (rdflib.term.URIRef('http://www.postsubmeta.net/foaf.rdf'),)
# (rdflib.term.URIRef('http://apassant.net/'),)
# (rdflib.term.URIRef('http://www.kr.tuwien.ac.at/staff/eiter/'),)
# (rdflib.term.Literal('Dan Brickley'),)
# (rdflib.term.URIRef('http://www.debruijn.net/#me'),)
# (rdflib.term.Literal("Ina O'Murchu"),)
# (rdflib.term.BNode('N37c878c77d0f4706a4fb76730762da67'),)
# (rdflib.term.Literal('Holger Lausen'),)
# (rdflib.term.URIRef('http://danbri.org/foaf.rdf#danbri'),)
# (rdflib.term.URIRef('http://www.deri.ie/'),)
# (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/PersonalProfileDocument'),)
# (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/Project'),)
# (rdflib.term.BNode('Nf8ea44caa87c48608987362ef89c232e'),)
# (rdflib.term.URIRef('http://sw.deri.org/~scorlosquet/foaf.rdf'),)
# (rdflib.term.BNode('Na89a16004b0f4f5fa7825d300a7123f1'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Knowledge_management'),)
# (rdflib.term.Literal('Brahmananda Sapkota', lang='en'),)
# (rdflib.term.URIRef('http://revyu.com/people/AxelPolleres'),)
# (rdflib.term.URIRef('http://www.real-programmer.com/'),)
# (rdflib.term.URIRef('http://g1o.net#me'),)
# (rdflib.term.URIRef('http://www.harth.org/andreas/foaf.rdf'),)
# (rdflib.term.URIRef('http://page.mi.fu-berlin.de/mochol/foaf.rdf#me'),)
# (rdflib.term.Literal('xel'),)
# (rdflib.term.Literal('Richard Cyganiak'),)
# (rdflib.term.Literal('James Scicluna'),)
# (rdflib.term.URIRef('http://kantenwerk.org'),)
# (rdflib.term.URIRef('http://www.polleres.net/metadata.rdf'),)
# (rdflib.term.BNode('N5eed1da22cc2413a9c8367b100a125b8'),)
# (rdflib.term.URIRef('http://www.ivan-herman.net/foaf.rdf'),)
# (rdflib.term.Literal('Knud Möller'),)
# (rdflib.term.URIRef('http://sw.deri.org/~bnsapkota/foaf.rdf#me'),)
# (rdflib.term.URIRef('http://www.deri.ie/about/team/member/Axel_Polleres#me'),)
# (rdflib.term.URIRef('http://www.deri.ie/fileadmin/scripts/foaf.php?id=64'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Austria'),)
# (rdflib.term.URIRef('http://www.wikier.org/foaf#wikier'),)
# (rdflib.term.URIRef('http://www.polleres.net/'),)
# (rdflib.term.URIRef('http://sw.deri.org/~bnsapkota/foaf.rdf'),)
# (rdflib.term.URIRef('http://www.sbg.at/divingdocmani/'),)
# (rdflib.term.URIRef('http://holgerlausen.net/foaf.rdf'),)
# (rdflib.term.URIRef('http://www.tuwien.ac.at/'),)
# (rdflib.term.Literal('Stefan Bischof'),)
# (rdflib.term.URIRef('http://eyaloren.org/foaf.rdf#me'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Semantic_Web'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Vienna'),)
# (rdflib.term.Literal('Thomas Krennwallner'),)
# (rdflib.term.URIRef('http://thefigtrees.net/lee/ldf-card#LDF'),)
# (rdflib.term.URIRef('http://www.postsubmeta.net/foaf.rdf#TK'),)
# (rdflib.term.BNode('Ndfa140ca5f5f441589c4463a27f884b2'),)
# (rdflib.term.URIRef('http://twitter2foaf.appspot.com/id/AxelPolleres'),)
# (rdflib.term.URIRef('http://data.semanticweb.org/person/axel-polleres'),)
# (rdflib.term.URIRef('http://sw.deri.org/~haller/foaf.rdf#ah'),)
# (rdflib.term.URIRef('http://www.scharffe.fr/foaf.rdf'),)
# (rdflib.term.Literal('ब्रह्मानन्द सापकोटा', lang='ne'),)
# (rdflib.term.Literal('Nuno Lopes'),)
# (rdflib.term.URIRef('http://www.facebook.com/AxelPolleres'),)
# (rdflib.term.URIRef('http://sw.deri.org/~scorlosquet/foaf.rdf#me'),)
# (rdflib.term.URIRef('http://sw.deri.org/~aidanh/foaf/foaf.rdf'),)
# (rdflib.term.URIRef('http://stefanbischof.at/foaf.rdf'),)
# (rdflib.term.URIRef('http://nets.ii.uam.es/~rlara/foaf.rdf'),)
# (rdflib.term.Literal('Roman Schindlauer'),)
# (rdflib.term.Literal('Michael Hausenblas'),)
# (rdflib.term.Literal('Andreas Harth'),)
# (rdflib.term.BNode('N64611fd0038d48c2bb013b94295d4321'),)
# (rdflib.term.URIRef('http://danbri.org/foaf.rdf'),)
# (rdflib.term.URIRef('http://www.google.com/profiles/droxel'),)
# (rdflib.term.Literal('Stéphane Corlosquet'),)
# (rdflib.term.URIRef('http://www.w3.org/2005/rules/wg/data#apollere2'),)
# (rdflib.term.BNode('N70959176b50c41d89591744ef56b215c'),)
# (rdflib.term.URIRef('http://www-di.inf.puc-rio.br/schwabe/foaf-schwabe.rdf'),)
# (rdflib.term.Literal('droxel'),)
# (rdflib.term.URIRef('http://semantictweet.com/AxelPolleres#me'),)
# (rdflib.term.URIRef('http://polleres.net/foaf.rdf'),)
# (rdflib.term.Literal('xl'),)
# (rdflib.term.URIRef('http://sw-app.org/mic.rdf'),)
# (rdflib.term.Literal('Giovambattista Ianni'),)
# (rdflib.term.URIRef('http://stefanbischof.at/foaf.rdf#me'),)
# (rdflib.term.URIRef('http://www.deri.org/'),)
# (rdflib.term.Literal('Manfred Pfeiffenberger'),)
# (rdflib.term.URIRef('http://www.wikier.org/'),)
# (rdflib.term.BNode('Ndb2d7b20eb0e4123aa0954fbcb13447b'),)
# (rdflib.term.BNode('Nab6a1b4522ab41e69d153452f2f1cb23'),)
# (rdflib.term.URIRef('http://page.mi.fu-berlin.de/~nixon/foaf.rdf#nixon'),)
# (rdflib.term.URIRef('http://sw-app.org/mic.xhtml#i'),)
# (rdflib.term.URIRef('http://www.aidanhogan.com/'),)
# (rdflib.term.URIRef('http://www.gibbi.com/'),)
# (rdflib.term.Literal('Eyal Oren'),)
# (rdflib.term.BNode('N2fd65c75115b4c91b9c093987e719edc'),)
# (rdflib.term.BNode('Nfa680cbba56b4e3782bc381493e48571'),)
# (rdflib.term.URIRef('http://holgerlausen.net/foaf.rdf#me'),)
# (rdflib.term.URIRef('http://dblp.l3s.de/d2r/resource/authors/Axel_Polleres'),)
# (rdflib.term.URIRef('http://www.kr.tuwien.ac.at/staff/former_staff/roman/foaf.rdf'),)
# (rdflib.term.URIRef('http://www.brg-kufstein.tsn.at/'),)
# (rdflib.term.URIRef('http://page.mi.fu-berlin.de/mochol/foaf.rdf'),)
# (rdflib.term.URIRef('http://www.aifb.uni-karlsruhe.de/Personen/viewPersonFOAF/foaf_2084.rdf'),)
# (rdflib.term.Literal('Charles Petrie'),)
# (rdflib.term.URIRef('http://www.ivan-herman.net/foaf.rdf#me'),)
# (rdflib.term.URIRef('http://www.deri.ie/fileadmin/scripts/foaf.php?id=124'),)
# (rdflib.term.URIRef('http://www.harth.org/andreas/'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Resource_Description_Framework'),)
# (rdflib.term.URIRef('http://www.w3.org/People/Eric/'),)
# (rdflib.term.URIRef('tel:+35391495723'),)
# (rdflib.term.URIRef('http://harth.org/andreas/foaf#ah'),)
# (rdflib.term.Literal('Stijn Heymans'),)
# (rdflib.term.URIRef('http://www.wfaber.com/foaf.rdf'),)
# (rdflib.term.Literal('James Hendler'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/SPARQL'),)
# (rdflib.term.Literal('John Breslin'),)
# (rdflib.term.BNode('N56e8273412714fb88235a72940a0af6d'),)
# (rdflib.term.Literal('03-24'),)
# (rdflib.term.URIRef('http://www.kr.tuwien.ac.at/staff/former_staff/roman/foaf.rdf#me'),)
# (rdflib.term.URIRef('http://www.ee.surrey.ac.uk/Personal/A.Zhdanova/foaf.rdf'),)
# (rdflib.term.Literal('Christoph Bussler'),)
# (rdflib.term.BNode('N14bbdbc04dba446e8eebaffdf8c50be5'),)
# (rdflib.term.Literal('Jos De Bruijn'),)
# (rdflib.term.URIRef('http://www.cs.rpi.edu/~hendler/foaf.rdf'),)
# (rdflib.term.Literal('Sergio Fernández'),)
# (rdflib.term.BNode('N8be1cc77139e4d788ed05d378636dc93'),)
# (rdflib.term.BNode('Nf4e5a9a5dd724fa49761ca3b69045b61'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Music'),)
# (rdflib.term.Literal('Wolfgang Faber'),)
# (rdflib.term.URIRef('http://stefanbischof.at/'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Logic_programming'),)
# (rdflib.term.Literal('Daniel Schwabe'),)
# (rdflib.term.URIRef('http://polleres.net/foaf.rdf#me'),)
# (rdflib.term.URIRef('http://www-di.inf.puc-rio.br/schwabe/foaf-schwabe.rdf#me'),)
# (rdflib.term.URIRef('http://sw.deri.org/~ina/foaf.rdf'),)
# (rdflib.term.URIRef('http://www.scharffe.fr/'),)
# (rdflib.term.URIRef('http://www.debruijn.net/foaf.rdf'),)
# (rdflib.term.Literal('Ivan Herman'),)
# (rdflib.term.Literal('40', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#int')),)
# (rdflib.term.URIRef('http://www.johnbreslin.com/'),)
# (rdflib.term.Literal('Rubén Lara Hernandez'),)
# (rdflib.term.Literal('Lee Feigenbaum'),)
# (rdflib.term.BNode('N631f444e4c9e4e6596e034256646fa0b'),)
# (rdflib.term.URIRef('http://www.aifb.uni-karlsruhe.de/Personen/viewPersonOWL/id2084instance'),)
# (rdflib.term.URIRef('http://www.manfredhauswirth.org/'),)
# (rdflib.term.URIRef('http://www.in-context.eu/'),)
# (rdflib.term.Literal('Lyndon J B Nixon'),)

# %% [markdown]
# ### Printing SPARQL results:
#
# An small example of filtering out the URIs only from a SPARQL result and printing them as a Comma separated list:

# %%
q = rdflib.plugins.sparql.prepareQuery(
        'SELECT ?s WHERE { ?person foaf:knows ?s .}',
        initNs = { "foaf": "http://xmlns.com/foaf/0.1/" })

g = rdflib.Graph()
g.load("http://polleres.net/foaf.rdf")

aidan = rdflib.URIRef("http://sw.deri.org/~aidanh/foaf/foaf.rdf#Aidan_Hogan")

# Variant 1:
# s=""
# for row in g.query(q):
#    if (type(row.s) is rdflib.term.URIRef):
#        if(len(s)): 
#            s = s + ', ' 
#        s = s + str(row.s) 
# print(s)

# Variant 2:
s=[]
for row in g.query(q):
    if (type(row.s) is rdflib.term.URIRef):
        s.append(str(row.s))
print(",\n".join(s))
# Out:
# http://harth.org/andreas/foaf#ah,
# http://www.johnbreslin.com/foaf/foaf.rdf#me,
# http://sw-app.org/mic.xhtml#i,
# http://www.postsubmeta.net/foaf.rdf#TK,
# http://eyaloren.org/foaf.rdf#me,
# http://stefanbischof.at/foaf.rdf#me,
# http://holgerlausen.net/foaf.rdf#me,
# http://thefigtrees.net/lee/ldf-card#LDF,
# http://g1o.net#me,
# http://sw.deri.org/~haller/foaf.rdf#ah,
# http://www-di.inf.puc-rio.br/schwabe/foaf-schwabe.rdf#me,
# http://www.aifb.uni-karlsruhe.de/Personen/viewPersonOWL/id2084instance,
# http://nets.ii.uam.es/~rlara/foaf.rdf#me,
# http://page.mi.fu-berlin.de/~nixon/foaf.rdf#nixon,
# http://www.ivan-herman.net/foaf.rdf#me,
# http://sw.deri.org/~bnsapkota/foaf.rdf#me,
# http://danbri.org/foaf.rdf#danbri,
# http://www.wikier.org/foaf#wikier,
# http://page.mi.fu-berlin.de/mochol/foaf.rdf#me,
# http://www.kr.tuwien.ac.at/staff/former_staff/roman/foaf.rdf#me,
# http://www.cs.rpi.edu/~hendler/foaf.rdf#jhendler,
# http://sw.deri.org/~aidanh/foaf/foaf.rdf#Aidan_Hogan,
# http://www.debruijn.net/#me,
# http://nunolopes.org/foaf.rdf#me,
# http://sw.deri.org/~scorlosquet/foaf.rdf#me,
# http://richard.cyganiak.de/foaf.rdf#cygri
